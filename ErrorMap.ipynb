# %%
from qiskit import IBMQ
from qiskit.visualization import plot_gate_map, plot_error_map

#provider = IBMQ.enable_account(token = '24fcdd25539433a92788dadd0e1a56d30e527bc55b9badb0ded8486f0b60ce5c4006997787da4908ec6f7ef7c8a7578246141c759c035cc880685300879e1194')
backend = provider.backends(simulator=False)[0]

fig = plot_gate_map(backend)
fig.savefig('gate_map.png')

fig = plot_error_map(backend)
fig.savefig('error_map.png')
